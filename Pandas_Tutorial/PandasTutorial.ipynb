# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "name":['harry','rohan','skillf','shubh'],
    "marks":[92,34,24,17],
    "city":['rampur','kolkata','bareilly','antartica']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks       city
# 0   harry     92     rampur
# 1   rohan     34    kolkata
# 2  skillf     24   bareilly
# 3   shubh     17  antartica

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends.csv', index=False)

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata

# %%
df.tail(2)
# Out:
#      name  marks       city
# 2  skillf     24   bareilly
# 3   shubh     17  antartica

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
harry = pd.read_csv('harry.csv')

# %%
harry
# Out:
#        name  marks       city
# 0     harry     92     rampur
# 1     rohan     34    kolkata
# 2    skillf     24   bareilly
# 3     shubh     17  antartica
# 4      prax     56       pune
# 5  rishabh      43    bharuch
# 6       sam     99      yemen

# %%
harry.index = ['first','second','third','fourth','fifth','sixth','seventh']

# %%
harry
# Out:
#              name  marks       city
# first       harry     92     rampur
# second      rohan     34    kolkata
# third      skillf     24   bareilly
# fourth      shubh     17  antartica
# fifth        prax     56       pune
# sixth    rishabh      43    bharuch
# seventh       sam     99      yemen

# %%
harry['marks']['second'] = 56
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_23484\3844006269.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   harry['marks']['second'] = 56
# C:\Users\prana\AppData\Local\Temp\ipykernel_23484\3844006269.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   harry['marks']['second'] = 56

# %%
harry
# Out:
#              name  marks       city
# first       harry     92     rampur
# second      rohan     56    kolkata
# third      skillf     24   bareilly
# fourth      shubh     17  antartica
# fifth        prax     56       pune
# sixth    rishabh      43    bharuch
# seventh       sam     99      yemen

# %%
harry['marks']
# Out:
# first      92
# second     56
# third      24
# fourth     17
# fifth      56
# sixth      43
# seventh    99
# Name: marks, dtype: int64

# %%
# harry.to_csv('Sam.csv') to save the changes again in a new file.

# %% [markdown]
# Pandas Data Structure:
#
# a) Series - It's a one dimensional array with indexes, it stores a single column or row of in a DataFrame.
#
# b) DataFrame - It's a tabular spreadsheet like structure representing rows each of which contains one or more multiple columns.

# %% [markdown]
# A one dimensional array capable of holding any type of data - Series
#
# A two dimensional data structure with columns of potentially different types of data - DataFrame

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.573841
# 1     0.139943
# 2     0.212391
# 3     0.289486
# 4     0.301307
# 5     0.104136
# 6     0.882197
# 7     0.502513
# 8     0.189547
# 9     0.748208
# 10    0.656174
# 11    0.947717
# 12    0.113074
# 13    0.853850
# 14    0.462733
# 15    0.090904
# 16    0.199235
# 17    0.269669
# 18    0.885776
# 19    0.708059
# 20    0.185184
# 21    0.743280
# 22    0.134834
# 23    0.853979
# 24    0.780803
# 25    0.612232
# 26    0.397035
# 27    0.386345
# 28    0.110488
# 29    0.253715
# 30    0.587038
# 31    0.332846
# 32    0.488720
# 33    0.279474
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index = np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.401816  0.741416  0.721137  0.819962  0.557667
# 1  0.250581  0.978830  0.430674  0.355318  0.591044
# 2  0.392727  0.389390  0.585826  0.723485  0.858466
# 3  0.900341  0.181705  0.347806  0.109279  0.693130
# 4  0.680877  0.466445  0.147482  0.912913  0.865702

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.401816  0.741416  0.721137  0.819962  0.557667
# 1    0.250581  0.978830  0.430674  0.355318  0.591044
# 2    0.392727  0.389390  0.585826  0.723485  0.858466
# 3    0.900341  0.181705  0.347806  0.109279  0.693130
# 4    0.680877  0.466445  0.147482  0.912913  0.865702
# ..        ...       ...       ...       ...       ...
# 329  0.150603  0.481350  0.618272  0.587523  0.623429
# 330  0.626683  0.980070  0.259111  0.260875  0.706219
# 331  0.606156  0.237516  0.361079  0.792388  0.051834
# 332  0.816152  0.015721  0.501135  0.045897  0.736706
# 333  0.930672  0.146324  0.275043  0.903660  0.456916
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
#
# [5 rows x 334 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0       0.3  0.741416  0.721137  0.819962  0.557667
# 1  0.250581  0.978830  0.430674  0.355318  0.591044
# 2  0.392727  0.389390  0.585826  0.723485  0.858466
# 3  0.900341  0.181705  0.347806  0.109279  0.693130
# 4  0.680877  0.466445  0.147482  0.912913  0.865702

# %%
newdf.sort_index(axis=0, ascending = False)
# Out:
#             0         1         2         3         4
# 333  0.930672  0.146324  0.275043  0.903660  0.456916
# 332  0.816152  0.015721  0.501135  0.045897  0.736706
# 331  0.606156  0.237516  0.361079  0.792388  0.051834
# 330  0.626683  0.980070  0.259111  0.260875  0.706219
# 329  0.150603  0.481350  0.618272  0.587523  0.623429
# ..        ...       ...       ...       ...       ...
# 4    0.680877  0.466445  0.147482  0.912913  0.865702
# 3    0.900341  0.181705  0.347806  0.109279  0.693130
# 2    0.392727  0.389390  0.585826  0.723485  0.858466
# 1    0.250581  0.978830  0.430674  0.355318  0.591044
# 0         0.3  0.741416  0.721137  0.819962  0.557667
#
# [334 rows x 5 columns]

# %%
newdf.sort_index(axis=1, ascending = False)
# Out:
#             4         3         2         1         0
# 0    0.557667  0.819962  0.721137  0.741416       0.3
# 1    0.591044  0.355318  0.430674  0.978830  0.250581
# 2    0.858466  0.723485  0.585826  0.389390  0.392727
# 3    0.693130  0.109279  0.347806  0.181705  0.900341
# 4    0.865702  0.912913  0.147482  0.466445  0.680877
# ..        ...       ...       ...       ...       ...
# 329  0.623429  0.587523  0.618272  0.481350  0.150603
# 330  0.706219  0.260875  0.259111  0.980070  0.626683
# 331  0.051834  0.792388  0.361079  0.237516  0.606156
# 332  0.736706  0.045897  0.501135  0.015721  0.816152
# 333  0.456916  0.903660  0.275043  0.146324  0.930672
#
# [334 rows x 5 columns]

# %%
 type(newdf[0])
# Out:
# pandas.core.series.Series

# %%
newdf.loc[0,0] = 654

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0       654  0.741416  0.721137  0.819962  0.557667
# 1  0.250581  0.978830  0.430674  0.355318  0.591044
# 2  0.392727  0.389390  0.585826  0.723485  0.858466
# 3  0.900341  0.181705  0.347806  0.109279  0.693130
# 4  0.680877  0.466445  0.147482  0.912913  0.865702

# %%
newdf.columns = list("ABCDE")

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0       654  0.741416  0.721137  0.819962  0.557667
# 1  0.250581  0.978830  0.430674  0.355318  0.591044
# 2  0.392727  0.389390  0.585826  0.723485  0.858466
# 3  0.900341  0.181705  0.347806  0.109279  0.693130
# 4  0.680877  0.466445  0.147482  0.912913  0.865702

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0       654  0.741416  0.721137  0.819962  0.557667
# 1  0.250581  0.978830  0.430674  0.355318  0.591044

# %%
newdf.loc[0,0] = 65433

# %%
newdf.head()
# Out:
#           A         B         C         D         E        0
# 0       654  0.741416  0.721137  0.819962  0.557667  65433.0
# 1  0.250581  0.978830  0.430674  0.355318  0.591044      NaN
# 2  0.392727  0.389390  0.585826  0.723485  0.858466      NaN
# 3  0.900341  0.181705  0.347806  0.109279  0.693130      NaN
# 4  0.680877  0.466445  0.147482  0.912913  0.865702      NaN

# %%
newdf.loc[0,'A'] = 4457

# %%
newdf.head()
# Out:
#           A         B         C         D         E        0
# 0      4457  0.741416  0.721137  0.819962  0.557667  65433.0
# 1  0.250581  0.978830  0.430674  0.355318  0.591044      NaN
# 2  0.392727  0.389390  0.585826  0.723485  0.858466      NaN
# 3  0.900341  0.181705  0.347806  0.109279  0.693130      NaN
# 4  0.680877  0.466445  0.147482  0.912913  0.865702      NaN

# %%
newdf.drop(0, axis=1)
# Out:
#             A         B         C         D         E
# 0        4457  0.741416  0.721137  0.819962  0.557667
# 1    0.250581  0.978830  0.430674  0.355318  0.591044
# 2    0.392727  0.389390  0.585826  0.723485  0.858466
# 3    0.900341  0.181705  0.347806  0.109279  0.693130
# 4    0.680877  0.466445  0.147482  0.912913  0.865702
# ..        ...       ...       ...       ...       ...
# 329  0.150603  0.481350  0.618272  0.587523  0.623429
# 330  0.626683  0.980070  0.259111  0.260875  0.706219
# 331  0.606156  0.237516  0.361079  0.792388  0.051834
# 332  0.816152  0.015721  0.501135  0.045897  0.736706
# 333  0.930672  0.146324  0.275043  0.903660  0.456916
#
# [334 rows x 5 columns]

# %%
newdf = newdf.drop(0, axis=1)

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0
inplace=True)

# %%
newdf
# Out:
#             B         D         E
# 0    0.741416  0.819962  0.557667
# 1    0.978830  0.355318  0.591044
# 2    0.389390  0.723485  0.858466
# 3    0.181705  0.109279  0.693130
# 4    0.466445  0.912913  0.865702
# ..        ...       ...       ...
# 329  0.481350  0.587523  0.623429
# 330  0.980070  0.260875  0.706219
# 331  0.237516  0.792388  0.051834
# 332  0.015721  0.045897  0.736706
# 333  0.146324  0.903660  0.456916
#
# [334 rows x 3 columns]

# %%
newdf.drop([1, 5], axis = 0, inplace=True)

# %%
newdf
# Out:
#             B         D         E
# 0    0.741416  0.819962  0.557667
# 2    0.389390  0.723485  0.858466
# 3    0.181705  0.109279  0.693130
# 4    0.466445  0.912913  0.865702
# 6    0.121154  0.388262  0.038082
# ..        ...       ...       ...
# 329  0.481350  0.587523  0.623429
# 330  0.980070  0.260875  0.706219
# 331  0.237516  0.792388  0.051834
# 332  0.015721  0.045897  0.736706
# 333  0.146324  0.903660  0.456916
#
# [332 rows x 3 columns]

# %%
newdf.head()
# Out:
#           B         D         E
# 0  0.741416  0.819962  0.557667
# 2  0.389390  0.723485  0.858466
# 3  0.181705  0.109279  0.693130
# 4  0.466445  0.912913  0.865702
# 6  0.121154  0.388262  0.038082

# %%
newdf.reset_index(drop=True, inplace = True)

# %%
newdf.head(3)
# Out:
#           B         D         E
# 0  0.741416  0.819962  0.557667
# 1  0.389390  0.723485  0.858466
# 2  0.181705  0.109279  0.693130

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
newdf['B'] = None

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 327    True
# 328    True
# 329    True
# 330    True
# 331    True
# Name: B, Length: 332, dtype: bool

# %%
newdf.loc[:, ['B']] = None

# %%
newdf
# Out:
#         B         D         E
# 0    None  0.819962  0.557667
# 1    None  0.723485  0.858466
# 2    None  0.109279  0.693130
# 3    None  0.912913  0.865702
# 4    None  0.388262  0.038082
# ..    ...       ...       ...
# 327  None  0.587523  0.623429
# 328  None  0.260875  0.706219
# 329  None  0.792388  0.051834
# 330  None  0.045897  0.736706
# 331  None  0.903660  0.456916
#
# [332 rows x 3 columns]

# %%
newdf.loc[:, ['B']] = 56

# %%
newdf
# Out:
#       B         D         E
# 0    56  0.819962  0.557667
# 1    56  0.723485  0.858466
# 2    56  0.109279  0.693130
# 3    56  0.912913  0.865702
# 4    56  0.388262  0.038082
# ..   ..       ...       ...
# 327  56  0.587523  0.623429
# 328  56  0.260875  0.706219
# 329  56  0.792388  0.051834
# 330  56  0.045897  0.736706
# 331  56  0.903660  0.456916
#
# [332 rows x 3 columns]

# %%
newdf.head()
# Out:
#     B         D         E
# 0  56  0.819962  0.557667
# 1  56  0.723485  0.858466
# 2  56  0.109279  0.693130
# 3  56  0.912913  0.865702
# 4  56  0.388262  0.038082

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Alfred'],
                    "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                    "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                             pd.NaT]})

# %%
df
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(how='all')
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT

# %%
df.dropna(how='all', axis=1)
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT

# %%
df.drop_duplicates()
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT

# %%
df.drop_duplicates(subset=['name'])
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25

# %%
df.drop_duplicates(subset=['name'], keep='first')
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25

# %%
df.drop_duplicates(subset=['name'], keep='last')
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT

# %%
df.drop_duplicates(subset=['name'], keep=False)
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 204.0+ bytes

# %%
df['name'].value_counts(dropna=False)
# Out:
# name
# Alfred    2
# Batman    1
# Name: count, dtype: int64

# %%
df['toy'].value_counts(dropna=False)
# Out:
# toy
# NaN          1
# Batmobile    1
# Bullwhip     1
# Name: count, dtype: int64

# %%
df['toy'].value_counts(dropna=True)
# Out:
# toy
# Batmobile    1
# Bullwhip     1
# Name: count, dtype: int64

# %%
df.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True   True   True
# 2  True   True  False

# %%
df.isnull()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True

# %%
# Create a dataframe which contains only integers with 3 rows and 2 columns
# run following dataframe methods on them:
# df.describe()
# df.mean()
# df.count()
# df.corr()
# df.max()
# df.min()
# df.median()
# df.std()

# %%
data = pd.read_excel('data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\prana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\prana\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 data = pd.read_excel('data.xlsx')
#
# File c:\Users\prana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\prana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File c:\Users\prana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)
#     539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)
#     550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File c:\Users\prana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
data
# Out:
#       Issue ID First Name Last Name  ATM ID  \
# 0   0d5ff8ed8d   Fredrick  Thompson   33562
# 1   d9c1547599      Patsy   Sheehan   66722
# 2   e0cb653f42        Jon      Snow    3351
# 3   94803beda8  Alexander     Ramos   37490
# 4   da18217bc3      Verna     Moore   77827
# 5   d146f1ccc1      Megan   Iverson   51428
# 6   045dbe3b7b       Paul     Edson   16252
# 7   d9d1df320a   Danielle      West   98308
# 8     JTXhApOb  Alexander     Ramos   37490
# 9     537b04c3       tech       cps  ATM007
# 10    t60538db       Issy      Wong  ATM789
# 11    c46732sp     Freeda       NaN  ATM456
#
#                                   Email                       Symptom  Photo  \
# 0   fredrick.thompson@fakeitcompany.com              ATM wont turn on    NaN
# 1       patsy.sheehan@fakeitcompany.com       Card reader not working    NaN
# 2            jon.snow@fakeitcompany.com                 Broken keypad    NaN
# 3     alexander.ramos@fakeitcompany.com               Low cash supply    NaN
# 4         verna.moore@fakeitcompany.com            Cash dispenser jam    NaN
# 5       megan.iverson@fakeitcompany.com              Connection error    NaN
# 6          paul.edson@fakeitcompany.com                    Not listed    NaN
# 7       danielle.west@fakeitcompany.com  Receipt printer out of paper    NaN
# 8     alexander.ramos@fakeitcompany.com    Receipt printer out of ink    NaN
# 9            tech.cps@fakeitcompany.com              ATM wont turn on    NaN
# 10       uk.benstokes@fakeitcompany.com              ATM wont turn on    NaN
# 11                                  NaN       Card reader not working    NaN
#
#                                          Description          Category  \
# 0                                ATM screen is black    General Issues
# 1                   The ATM is not recognizing cards    General Issues
# 2                  The 2 on the keypad isn't working    General Issues
# 3   ATM dispensed 2 $10 bills, instead of 1 $20 bill    Cash Dispenser
# 4                                      Cash is stuck    Cash Dispenser
# 5                   Cannot connect to bank's network  Connection error
# 6               ATM is not recognizing a correct PIN    General Issues
# 7                               Receipt didn't print          Receipts
# 8                              Receipt printed blank          Receipts
# 9                                                NaN    General Issues
# 10                                               NaN    General Issues
# 11                                               NaN    General Issues
#
#      Assigned Tech        Date Created  Resolved  Notes  Date Resolved
# 0   Shelley Ginder 2016-10-13 18:06:00      True    NaN            NaN
# 1    Justin Sample 2016-10-14 18:06:00      True    NaN            NaN
# 2   Shelley Ginder 2016-10-15 18:06:00      True    NaN            NaN
# 3     Miles Barron 2016-10-16 18:06:00      True    NaN            NaN
# 4     Miles Barron 2016-10-17 18:06:00     False    NaN            NaN
# 5        Nia Jones 2016-10-18 18:06:00     False    NaN            NaN
# 6    Justin Sample 2016-10-19 18:06:00     False    NaN            NaN
# 7       Jean Clark 2016-10-20 18:06:00     False    NaN            NaN
# 8       Jean Clark 2016-10-21 18:06:00     False    NaN            NaN
# 9   Shelley Ginder 2023-12-17 20:26:00     False    NaN            NaN
# 10  Shelley Ginder 2023-12-17 20:26:00     False    NaN            NaN
# 11  Shelley Ginder 2023-12-17 20:26:00     False    NaN            NaN

# %%
data.iloc[0,0] =34

# %%
data
# Out:
#       Issue ID First Name Last Name  ATM ID  \
# 0           34   Fredrick  Thompson   33562
# 1   d9c1547599      Patsy   Sheehan   66722
# 2   e0cb653f42        Jon      Snow    3351
# 3   94803beda8  Alexander     Ramos   37490
# 4   da18217bc3      Verna     Moore   77827
# 5   d146f1ccc1      Megan   Iverson   51428
# 6   045dbe3b7b       Paul     Edson   16252
# 7   d9d1df320a   Danielle      West   98308
# 8     JTXhApOb  Alexander     Ramos   37490
# 9     537b04c3       tech       cps  ATM007
# 10    t60538db       Issy      Wong  ATM789
# 11    c46732sp     Freeda       NaN  ATM456
#
#                                   Email                       Symptom  Photo  \
# 0   fredrick.thompson@fakeitcompany.com              ATM wont turn on    NaN
# 1       patsy.sheehan@fakeitcompany.com       Card reader not working    NaN
# 2            jon.snow@fakeitcompany.com                 Broken keypad    NaN
# 3     alexander.ramos@fakeitcompany.com               Low cash supply    NaN
# 4         verna.moore@fakeitcompany.com            Cash dispenser jam    NaN
# 5       megan.iverson@fakeitcompany.com              Connection error    NaN
# 6          paul.edson@fakeitcompany.com                    Not listed    NaN
# 7       danielle.west@fakeitcompany.com  Receipt printer out of paper    NaN
# 8     alexander.ramos@fakeitcompany.com    Receipt printer out of ink    NaN
# 9            tech.cps@fakeitcompany.com              ATM wont turn on    NaN
# 10       uk.benstokes@fakeitcompany.com              ATM wont turn on    NaN
# 11                                  NaN       Card reader not working    NaN
#
#                                          Description          Category  \
# 0                                ATM screen is black    General Issues
# 1                   The ATM is not recognizing cards    General Issues
# 2                  The 2 on the keypad isn't working    General Issues
# 3   ATM dispensed 2 $10 bills, instead of 1 $20 bill    Cash Dispenser
# 4                                      Cash is stuck    Cash Dispenser
# 5                   Cannot connect to bank's network  Connection error
# 6               ATM is not recognizing a correct PIN    General Issues
# 7                               Receipt didn't print          Receipts
# 8                              Receipt printed blank          Receipts
# 9                                                NaN    General Issues
# 10                                               NaN    General Issues
# 11                                               NaN    General Issues
#
#      Assigned Tech        Date Created  Resolved  Notes  Date Resolved
# 0   Shelley Ginder 2016-10-13 18:06:00      True    NaN            NaN
# 1    Justin Sample 2016-10-14 18:06:00      True    NaN            NaN
# 2   Shelley Ginder 2016-10-15 18:06:00      True    NaN            NaN
# 3     Miles Barron 2016-10-16 18:06:00      True    NaN            NaN
# 4     Miles Barron 2016-10-17 18:06:00     False    NaN            NaN
# 5        Nia Jones 2016-10-18 18:06:00     False    NaN            NaN
# 6    Justin Sample 2016-10-19 18:06:00     False    NaN            NaN
# 7       Jean Clark 2016-10-20 18:06:00     False    NaN            NaN
# 8       Jean Clark 2016-10-21 18:06:00     False    NaN            NaN
# 9   Shelley Ginder 2023-12-17 20:26:00     False    NaN            NaN
# 10  Shelley Ginder 2023-12-17 20:26:00     False    NaN            NaN
# 11  Shelley Ginder 2023-12-17 20:26:00     False    NaN            NaN

# %%
data.to_excel('data.xlsx', sheet_name='Sheet1')
