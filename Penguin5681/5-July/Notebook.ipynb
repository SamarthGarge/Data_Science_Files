# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\prana\PycharmProjects\Data_Science_Files\Datasets\churn.csv")
df
# Out:
#          State  Account Length  Area Code Int'l Plan VMail Plan  \
# Phone
# 382-4657    KS             128        415         no        yes
# 371-7191    OH             107        415         no        yes
# 358-1921    NJ             137        415         no         no
# 375-9999    OH              84        408        yes         no
# 330-6626    OK              75        415        yes         no
# ...        ...             ...        ...        ...        ...
# 414-4276    AZ             192        415         no        yes
# 370-3271    WV              68        415         no         no
# 328-8230    RI              28        510         no         no
# 364-6381    CT             184        510        yes         no
# 400-4344    TN              74        415         no        yes
#
#           VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# Phone
# 382-4657             25     265.1        110       45.07     197.4         99
# ...

# %%
df = pd.read_csv(r"C:\Users\prana\PycharmProjects\Data_Science_Files\Datasets\churn.csv", index_col='Phone')
df
# Out:
#          State  Account Length  Area Code Int'l Plan VMail Plan  \
# Phone
# 382-4657    KS             128        415         no        yes
# 371-7191    OH             107        415         no        yes
# 358-1921    NJ             137        415         no         no
# 375-9999    OH              84        408        yes         no
# 330-6626    OK              75        415        yes         no
# ...        ...             ...        ...        ...        ...
# 414-4276    AZ             192        415         no        yes
# 370-3271    WV              68        415         no         no
# 328-8230    RI              28        510         no         no
# 364-6381    CT             184        510        yes         no
# 400-4344    TN              74        415         no        yes
#
#           VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# Phone
# 382-4657             25     265.1        110       45.07     197.4         99
# ...

# %%
len(df.columns) # or df.columns
# Out:
# 20

# %%
df.isnull()
# Out:
#           State  Account Length  Area Code  Int'l Plan  VMail Plan  \
# Phone
# 382-4657  False           False      False       False       False
# 371-7191  False           False      False       False       False
# 358-1921  False           False      False       False       False
# 375-9999  False           False      False       False       False
# 330-6626  False           False      False       False       False
# ...         ...             ...        ...         ...         ...
# 414-4276  False           False      False       False       False
# 370-3271  False           False      False       False       False
# 328-8230  False           False      False       False       False
# 364-6381  False           False      False       False       False
# 400-4344  False           False      False       False       False
#
#           VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# Phone
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.isnull().sum()
# Out:
# State             0
# Account Length    0
# Area Code         0
# Int'l Plan        0
# VMail Plan        0
# VMail Message     0
# Day Mins          0
# Day Calls         0
# Day Charge        0
# Eve Mins          0
# Eve Calls         0
# Eve Charge        0
# Night Mins        0
# Night Calls       0
# Night Charge      0
# Intl Mins         0
# Intl Calls        0
# Intl Charge       0
# CustServ Calls    0
# Churn?            0
# dtype: int64

# %%
df.dropna() # Drops the erow with even a single null cell
# Out:
#          State  Account Length  Area Code Int'l Plan VMail Plan  \
# Phone
# 382-4657    KS             128        415         no        yes
# 371-7191    OH             107        415         no        yes
# 358-1921    NJ             137        415         no         no
# 375-9999    OH              84        408        yes         no
# 330-6626    OK              75        415        yes         no
# ...        ...             ...        ...        ...        ...
# 414-4276    AZ             192        415         no        yes
# 370-3271    WV              68        415         no         no
# 328-8230    RI              28        510         no         no
# 364-6381    CT             184        510        yes         no
# 400-4344    TN              74        415         no        yes
#
#           VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# Phone
# 382-4657             25     265.1        110       45.07     197.4         99
# ...

# %%
df.describe()
# Out:
#        Account Length    Area Code  VMail Message     Day Mins    Day Calls  \
# count     3333.000000  3333.000000    3333.000000  3333.000000  3333.000000
# mean       101.064806   437.182418       8.099010   179.775098   100.435644
# std         39.822106    42.371290      13.688365    54.467389    20.069084
# min          1.000000   408.000000       0.000000     0.000000     0.000000
# 25%         74.000000   408.000000       0.000000   143.700000    87.000000
# 50%        101.000000   415.000000       0.000000   179.400000   101.000000
# 75%        127.000000   510.000000      20.000000   216.400000   114.000000
# max        243.000000   510.000000      51.000000   350.800000   165.000000
#
#         Day Charge     Eve Mins    Eve Calls   Eve Charge   Night Mins  \
# count  3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean     30.562307   200.980348   100.114311    17.083540   200.872037
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3333 entries, 382-4657 to 400-4344
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           3333 non-null   object
#  1   Account Length  3333 non-null   int64
#  2   Area Code       3333 non-null   int64
#  3   Int'l Plan      3333 non-null   object
#  4   VMail Plan      3333 non-null   object
#  5   VMail Message   3333 non-null   int64
#  6   Day Mins        3333 non-null   float64
#  7   Day Calls       3333 non-null   int64
#  8   Day Charge      3333 non-null   float64
#  9   Eve Mins        3333 non-null   float64
#  10  Eve Calls       3333 non-null   int64
#  11  Eve Charge      3333 non-null   float64
#  12  Night Mins      3333 non-null   float64
#  13  Night Calls     3333 non-null   int64
#  14  Night Charge    3333 non-null   float64
#  15  Intl Mins       3333 non-null   float64
#  16  Intl Calls      3333 non-null   int64
# ...
