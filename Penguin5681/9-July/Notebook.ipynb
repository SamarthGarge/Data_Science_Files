# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as mp

# %%
df = pd.read_csv(r'C:\Users\prana\PycharmProjects\Data_Science_Files\Datasets\WineDataset.csv')
df
# Out:
#                                                   Title  \
# 0                                    The Guv'nor, Spain
# 1     Bread & Butter 'Winemaker's Selection' Chardon...
# 2          Oyster Bay Sauvignon Blanc 2022, Marlborough
# 3                      Louis Latour Mâcon-Lugny 2021/22
# 4     Bread & Butter 'Winemaker's Selection' Pinot N...
# ...                                                 ...
# 1285    Vouvray Sec 'Expresion de Silex' 2020/21, Loire
# 1286        Waimea Estates Pinot Noir Rosé 2021, Nelson
# 1287      Wakefield 'Visionary' Cabernet Sauvignon 2010
# 1288  Yalumba 'The Menzies' Cabernet Sauvignon 2015/...
# 1289     Yalumba 'Virgilius' Viognier 2017, Eden Valley
#
#                                             Description              Price  \
# 0     We asked some of our most prized winemakers wo...   £9.99 per bottle
# 1     This really does what it says on the tin. It’s...  £15.99 per bottle
# ...

# %%
df.shape
# Out:
# (1290, 17)

# %%
df[['Grape', 'Unit', 'Price']]   # Returns only specific cols
# Out:
#                    Grape  Unit              Price
# 0            Tempranillo  10.5   £9.99 per bottle
# 1             Chardonnay  10.1  £15.99 per bottle
# 2        Sauvignon Blanc   9.8  £12.49 per bottle
# 3             Chardonnay  10.1  £17.99 per bottle
# 4             Pinot Noir  10.1  £15.99 per bottle
# ...                  ...   ...                ...
# 1285        Chenin Blanc   9.4  £11.99 per bottle
# 1286          Pinot Noir   9.8  £13.99 per bottle
# 1287  Cabernet Sauvignon  10.1  £85.00 per bottle
# 1288  Cabernet Sauvignon  10.9  £37.99 per bottle
# 1289            Viognier  10.1  £34.99 per bottle
#
# [1290 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Title                          0
# Description                    4
# Price                          0
# Capacity                       0
# Grape                         15
# Secondary Grape Varieties    802
# Closure                       11
# Country                        6
# Unit                           9
# Characteristics               37
# Per bottle / case / each       0
# Type                           5
# ABV                            9
# Region                       166
# Style                         78
# Vintage                        7
# Appellation                  646
# dtype: int64

# %%
df.replace(0, np.nan, inplace=True)

# %%
df.dropna()
df[['Title', 'Price']]
# Out:
#                                                   Title              Price
# 0                                    The Guv'nor, Spain   £9.99 per bottle
# 1     Bread & Butter 'Winemaker's Selection' Chardon...  £15.99 per bottle
# 2          Oyster Bay Sauvignon Blanc 2022, Marlborough  £12.49 per bottle
# 3                      Louis Latour Mâcon-Lugny 2021/22  £17.99 per bottle
# 4     Bread & Butter 'Winemaker's Selection' Pinot N...  £15.99 per bottle
# ...                                                 ...                ...
# 1285    Vouvray Sec 'Expresion de Silex' 2020/21, Loire  £11.99 per bottle
# 1286        Waimea Estates Pinot Noir Rosé 2021, Nelson  £13.99 per bottle
# 1287      Wakefield 'Visionary' Cabernet Sauvignon 2010  £85.00 per bottle
# 1288  Yalumba 'The Menzies' Cabernet Sauvignon 2015/...  £37.99 per bottle
# 1289     Yalumba 'Virgilius' Viognier 2017, Eden Valley  £34.99 per bottle
#
# [1290 rows x 2 columns]

# %%
text = df.Description[0]
text1 = df["Description"][0]
text
# Out:
# "We asked some of our most prized winemakers working in Spain to make the best wines possible – no rules, no restrictions, no red tape. The Guv'nor collection was their answer. Made from Tempranillo grapes picked from their favourite vineyards across Spain, it’s a crowd-pleasing wine designed to be shared with good food – and even better company. It’s bold. It’s fruity. It’s a modern Spanish red that goes with everything, especially spicy barbecue meats or anything chargrilled."

# %%
obj = WordCloud().generate(text=text)
obj

# %%
mp.imshow(obj, interpolation='bilinear')
