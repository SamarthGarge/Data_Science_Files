# %% [markdown]
# ## Refer [Matplotlib Documentation](https://matplotlib.org/stable/users/explain/quick_start.html) for more fancy explanation

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Drawing a simple plot

# %%
mtCarsDataFrame = pd.read_csv(r'C:\Users\prana\PycharmProjects\Data_Science_Files\Datasets\mtcars.csv')

mtCarsDataFrame.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
figure, axes = plt.subplots()   # Generates an empty Axes plot

axes.plot(mtCarsDataFrame['disp'], mtCarsDataFrame['hp'])
axes.set_xlabel('disp')
axes.set_ylabel('hp')
# Out:
# Text(0, 0.5, 'hp')

# %% [markdown]
# ## Explanation for the above plot

# %%
# Consider two numpy arrays
x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([10, 5, 4, 3, 10, 1])


fig, ax = plt.subplots()
ax.plot(x, y)


# Notice how the plot has been made
# It is made as (x, y) i.e in our case, the plots has been made in the following order
# (1, 10) (2, 5) (3, 4) (4, 3) (5, 10) (6, 1)

# %% [markdown]
# # Drawing a scattered plot
# ## Using the previously declared mtcars dataset

# %%
mtCarsDataFrame.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
plt.scatter(x=mtCarsDataFrame['disp'], y=mtCarsDataFrame['wt'])

# %% [markdown]
# ## Understanding the above plot
#
# ### Remember the first plot?
# ### This is exact same as that, just don't connect the lines ;)

# %%
# Here's the proof anyways x, y are the same old numpy arrays
plt.scatter(x, y)
plt.show()

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Object Oriented (OO) Plots
# ## Graphs of a math function basically
#
# ### Plots for the following functions
# ### $f(x) = x$
# ### $f(x) = x^2$
# ### $f(x) = x^3$

# %%
# linspace(start, stop, number_of_samples)
# Generates numbers with constant difference
# In this case the difference of any two consecutive numebers is 0.02020202

x = np.linspace(0, 2, 100)

fig, ax = plt.subplots()
ax.plot(x, x, label='linear')

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, label='quadratic')

# %%
fig, ax = plt.subplots()
ax.plot(x, x**3, label='cubic')

# %% [markdown]
# ## Merging the above the plots into one and making it look nice

# %%
fig, ax = plt.subplots()

ax.plot(x, x, label='linear')
ax.plot(x, x**2, label='quadratic')
ax.plot(x, x**3, label='cubic')
ax.legend() # We have added labels to show in the legend, else it is not required

# %% [markdown]
# ## Note: All the above plots can be made using PyPlot
# ### for example
# ``` python
# plt.plot(x, x, label='linear')
# plt.plot(x, x**2, label='quadratic')
# plt.plot(x, x**3, label='cubic')
# plt.legend()
# ```
