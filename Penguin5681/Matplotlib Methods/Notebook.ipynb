# %% [markdown]
# ## [Matplotlib Documentation](https://matplotlib.org/stable/users/explain/quick_start.html)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dataFrame = pd.read_csv(r'C:\Users\prana\PycharmProjects\Data_Science_Files\Datasets\mtcars.csv')

dataFrame.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
figure, axes = plt.subplots()   # Generates an empty Axes plot

axes.plot(dataFrame['disp'], dataFrame['hp'])
axes.set_xlabel('disp')
axes.set_ylabel('hp')
# Out:
# Text(0, 0.5, 'hp')
