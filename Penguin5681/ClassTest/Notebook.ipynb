# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### read_csv() is used for reading the csv (comma separated values)

# %%
df = pd.read_csv(r'C:\Users\prana\PycharmProjects\Data_Science_Files\Datasets\WineDataset.csv')
df
# Out:
#                                                   Title  \
# 0                                    The Guv'nor, Spain
# 1     Bread & Butter 'Winemaker's Selection' Chardon...
# 2          Oyster Bay Sauvignon Blanc 2022, Marlborough
# 3                      Louis Latour Mâcon-Lugny 2021/22
# 4     Bread & Butter 'Winemaker's Selection' Pinot N...
# ...                                                 ...
# 1285    Vouvray Sec 'Expresion de Silex' 2020/21, Loire
# 1286        Waimea Estates Pinot Noir Rosé 2021, Nelson
# 1287      Wakefield 'Visionary' Cabernet Sauvignon 2010
# 1288  Yalumba 'The Menzies' Cabernet Sauvignon 2015/...
# 1289     Yalumba 'Virgilius' Viognier 2017, Eden Valley
#
#                                             Description              Price  \
# 0     We asked some of our most prized winemakers wo...   £9.99 per bottle
# 1     This really does what it says on the tin. It’s...  £15.99 per bottle
# ...

# %% [markdown]
# ### head => returns the first 5 rows
# ### tail => returns the last 5 rows

# %%
df.head()
# Out:
#                                                Title  \
# 0                                 The Guv'nor, Spain
# 1  Bread & Butter 'Winemaker's Selection' Chardon...
# 2       Oyster Bay Sauvignon Blanc 2022, Marlborough
# 3                   Louis Latour Mâcon-Lugny 2021/22
# 4  Bread & Butter 'Winemaker's Selection' Pinot N...
#
#                                          Description              Price  \
# 0  We asked some of our most prized winemakers wo...   £9.99 per bottle
# 1  This really does what it says on the tin. It’s...  £15.99 per bottle
# 2  Oyster Bay has been an award-winning gold-stan...  £12.49 per bottle
# 3  We’ve sold this wine for thirty years – and fo...  £17.99 per bottle
# 4  Bread & Butter is that thing that you can coun...  £15.99 per bottle
#
#   Capacity            Grape Secondary Grape Varieties       Closure  \
# 0     75CL      Tempranillo                       NaN  Natural Cork
# 1     75CL       Chardonnay                       NaN  Natural Cork
# ...

# %%
df.tail()
# Out:
#                                                   Title  \
# 1285    Vouvray Sec 'Expresion de Silex' 2020/21, Loire
# 1286        Waimea Estates Pinot Noir Rosé 2021, Nelson
# 1287      Wakefield 'Visionary' Cabernet Sauvignon 2010
# 1288  Yalumba 'The Menzies' Cabernet Sauvignon 2015/...
# 1289     Yalumba 'Virgilius' Viognier 2017, Eden Valley
#
#                                             Description              Price  \
# 1285  Although Denis Meunier is only in his late 20s...  £11.99 per bottle
# 1286  Waimea’s vineyards are less than 1km from the ...  £13.99 per bottle
# 1287  Made from the very best fruit nourished by 40-...  £85.00 per bottle
# 1288  In 1961, Sir Robert Menzies said that Yalumba'...  £37.99 per bottle
# 1289  Yalumba's Virgilius is often regarded as Austr...  £34.99 per bottle
#
#      Capacity               Grape Secondary Grape Varieties       Closure  \
# 1285     75CL        Chenin Blanc                       NaN  Natural Cork
# ...

# %% [markdown]
# ### columns => returns the column names

# %%
df.columns
# Out:
# Index(['Title', 'Description', 'Price', 'Capacity', 'Grape',
#        'Secondary Grape Varieties', 'Closure', 'Country', 'Unit',
#        'Characteristics', 'Per bottle / case / each', 'Type', 'ABV', 'Region',
#        'Style', 'Vintage', 'Appellation'],
#       dtype='object')

# %% [markdown]
# ### shape => returns the size (m x n)

# %%
df.shape
# Out:
# (1290, 17)

# %% [markdown]
# ### isnull() => checks for null cells
# ### False => not null
# ### True => null

# %%
df.isnull()
# Out:
#       Title  Description  Price  Capacity  Grape  Secondary Grape Varieties  \
# 0     False        False  False     False  False                       True
# 1     False        False  False     False  False                       True
# 2     False        False  False     False  False                       True
# 3     False        False  False     False  False                       True
# 4     False        False  False     False  False                       True
# ...     ...          ...    ...       ...    ...                        ...
# 1285  False        False  False     False  False                       True
# 1286  False        False  False     False  False                       True
# 1287  False        False  False     False  False                       True
# 1288  False        False  False     False  False                       True
# 1289  False        False  False     False  False                       True
#
# ...

# %% [markdown]
# ### isNull().sum() => returns the null cell count

# %%
df.isnull().sum()
# Out:
# Title                          0
# Description                    4
# Price                          0
# Capacity                       0
# Grape                         15
# Secondary Grape Varieties    802
# Closure                       11
# Country                        6
# Unit                           9
# Characteristics               37
# Per bottle / case / each       0
# Type                           5
# ABV                            9
# Region                       166
# Style                         78
# Vintage                        7
# Appellation                  646
# dtype: int64

# %% [markdown]
# ### dropna() => drops the row with a null cell (entire row is dropped even if a single cell is null)

# %%
df.dropna()
# Out:
#                                                   Title  \
# 13              Miraval Rosé 2021/22, Côtes de Provence
# 15    Peyrassol 'Réserve des Templiers' Rosé 2022, C...
# 18    Caves d'Esclans 'Whispering Angel' Rosé 2022, ...
# 27    Château de Berne ‘Inspiration’ Rosé 2021/22, C...
# 28    Domaine La Chautarde Rosé 2022, Côteaux Varois...
# ...                                                 ...
# 1224  Rutherglen Shelley's Block Marsanne, Viognier,...
# 1233                        Sassicaia 2019/20, Bolgheri
# 1242  Stag's Leap 'Hands of Time' Red Blend 2018/19,...
# 1264                    Torbreck Descendant Shiraz 2012
# 1265  Torbreck 'Runrig' Shiraz 2012/2014, Barossa Va...
#
#                                             Description               Price  \
# 13    Miraval shot to fame when Angelina Jolie and B...   £22.99 per bottle
# 15    La Commanderie de Peyrassol was established in...   £15.99 per bottle
# ...

# %% [markdown]
# ### describe() returns the statistical data within a csv

# %%
df.describe()
# Out:
#               Unit
# count  1281.000000
# mean     10.177674
# std       2.318850
# min       0.000000
# 25%       9.400000
# 50%      10.100000
# 75%      10.500000
# max      39.000000

# %% [markdown]
# ### info() => returns the data type and other related information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1290 entries, 0 to 1289
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Title                      1290 non-null   object
#  1   Description                1286 non-null   object
#  2   Price                      1290 non-null   object
#  3   Capacity                   1290 non-null   object
#  4   Grape                      1275 non-null   object
#  5   Secondary Grape Varieties  488 non-null    object
#  6   Closure                    1279 non-null   object
#  7   Country                    1284 non-null   object
#  8   Unit                       1281 non-null   float64
#  9   Characteristics            1253 non-null   object
#  10  Per bottle / case / each   1290 non-null   object
#  11  Type                       1285 non-null   object
#  12  ABV                        1281 non-null   object
# ...

# %% [markdown]
# ### Accessing the columns using [] or .
# ### eg. df.Unit[0] => returns the first data (10.5 in my dataset)

# %%
df.Unit
# Out:
# 0       10.5
# 1       10.1
# 2        9.8
# 3       10.1
# 4       10.1
#         ...
# 1285     9.4
# 1286     9.8
# 1287    10.1
# 1288    10.9
# 1289    10.1
# Name: Unit, Length: 1290, dtype: float64

# %%
df.Unit[0]
# Out:
# np.float64(10.5)

# %% [markdown]
# ### Deep and Shallow Copy
# ### view() and copy()
#
# ### view() => will keep the copy of the array updated
