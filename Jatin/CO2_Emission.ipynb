# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df=pd.read_csv(r"C:\Users\jatin\PycharmProjects\Data_Science_Files\Datasets\CO2 Emissions_Canada.csv")
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %% [markdown]
# ### Drop method removes the method which we give

# %%
df.drop(["Make","Model","Vehicle Class","Transmission","Fuel Type","Fuel Consumption Hwy (L/100 km)","Fuel Consumption Comb (L/100 km)","Fuel Consumption Comb (mpg)"],axis=1,inplace=True)

# %%
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       CO2 Emissions(g/km)
# 0                     196
# 1                     221
# 2                     136
# 3                     255
# 4                     244
# ...

# %%
# to create graph
sb.lmplot(data=df,x="Engine Size(L)",y="CO2 Emissions(g/km)", line_kws={'color':'#000'})

# %%
xbar = df['Engine Size(L)'].mean()
ybar = df['CO2 Emissions(g/km)'].mean()

# %%
print(xbar,ybar)
# Out:
# 3.160067704807041 250.58469871360867

# %%
##  sigma(x-xBar)*(y-yBar) / sigma(x-xBar)**2

# %%
df["numerator"]=((df["Engine Size(L)"]-xbar)*(df["CO2 Emissions(g/km)"]-ybar)).sum()
df["denominator"]=((df["Engine Size(L)"]-xbar)**2).sum()
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       CO2 Emissions(g/km)      numerator   denominator
# 0                     196  497987.427651  13540.613966
# 1                     221  497987.427651  13540.613966
# ...

# %%
theta1=df["numerator"]/df["denominator"]
theta1
# Out:
# 0       36.777315
# 1       36.777315
# 2       36.777315
# 3       36.777315
# 4       36.777315
#           ...
# 7380    36.777315
# 7381    36.777315
# 7382    36.777315
# 7383    36.777315
# 7384    36.777315
# Length: 7385, dtype: float64
